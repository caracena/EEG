# %%
# %matplotlib inline

# %%
import numpy
import random
from scipy import stats
import matplotlib.pyplot as plt

# %%
def getTimeSeries(n,i,f):
    cont = []
    for x in range(n):
        cont.append(random.randint(i, f))
    return stats.zscore(cont)

# %%
def getBackward(seq,k):
    return numpy.diff(seq,n=k)

# %%
a = getTimeSeries(1000, 0, 10)
plt.plot(a)
plt.show()

# %%
x      = []
b_cont = []
for k in range(50):  #order
    b  = getBackward(a,k)
    b_cont.append(b)
    for t in range(len(b)):
        x.append((1 if b[t] >= 0 else 0,k,t))  # formato : 0/1 , k ,t

# %%
for b in b_cont:
    plt.plot(b)
plt.show()

# %%
d = []
for k in range(50):
    temp = []
    for i in range(len(x)):
        if x[i][1] == k:
            temp.append(x[i][0]) # 0 o 1
    sum = 0
    for j in range(len(temp)):
        sum = sum + pow(temp[j] - temp[j-1],2)
    d.append(sum)

# %%
print d
# Out:
# [504, 658, 720, 770, 800, 818, 824, 842, 858, 864, 868, 868, 872, 876, 878, 880, 884, 886, 894, 894, 894, 894, 894, 894, 892, 896, 894, 896, 894, 894, 894, 892, 892, 890, 892, 892, 892, 892, 890, 894, 894, 894, 892, 892, 890, 890, 888, 888, 886, 886]

# %%
plt.plot(d)
plt.show()
